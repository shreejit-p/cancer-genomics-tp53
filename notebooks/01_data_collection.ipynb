# %%
# Import required BioPython modules
from Bio import Entrez
from Bio import SeqIO

# %%
# Set the Entrez email
Entrez.email = "shreejit.data@gmail.com"

# %%
#Search for TP53 genes in humans
search_handle = Entrez.esearch(
    db = "nucleotide",
    term = "TP53[Gene] AND Homo sapiens[Organism]",
    retmax = 10
)
search_results = Entrez.read(search_handle)
search_handle.close()
# Extract list of IDs
id_list = search_results["IdList"]
print("Retrieved IDs:")
print(id_list)
# Out:
# Retrieved IDs:
# ['383209646', '3211419055', '3135759503', '3135759501', '3135759499', '2194972897', '568815581', '2246031203', '1894803104', '1894803103']
